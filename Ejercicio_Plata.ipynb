# %% [markdown]
# <a href="https://colab.research.google.com/github/21Maryori/EjerciciodelaPlata/blob/main/Ejercicio_Plata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
datos = pd.read_csv("https://docs.google.com/spreadsheets/d/e/2PACX-1vRCoVPLdERfs3e1GW3VvBCOG5gHu2kI9pZxii3IHUPFtzAkGAN23LDu6mlvr8na1FjD00L_nyy1-nB9/pub?gid=1734700428&single=true&output=csv", index_col="Fecha",)

# %%
datos
# Out:
#             Peru  Bolivia  Brazil  Argentina  Chile  Mexico  Alemania
# Fecha
# 20/03/2020     1        1       0          0      0       3         0
# 21/03/2020    21       16       8          7      3      31         2
# 22/03/2020    31       17      19         18      4      45         4
# 23/03/2020    35       25      31         26      8      41         6
# 24/03/2020    22       34      43         34      9      47         7
# 25/03/2020    36       38      55         38     12      60         9
# 26/03/2020    54       17      66         49     17      77        11
# 27/03/2020    68       21      74         50     22      98        13
# 28/03/2020    79       20      89         51     24      77        14
# 29/03/2020    28       34      93         59     29      58        15
# 30/03/2020    37       40     101         60     32      42        17
# 31/03/2020    46       41     110         68     34      42        18
# ...

# %%
# !pip install bar-chart-race

# %%
import bar_chart_race as bcarrera

# %%
bcarrera.bar_chart_race(df=datos,filename="Mivideograficos.mp4")
# Out:
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:286: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_yticklabels(self.df_values.columns)
# /usr/local/lib/python3.10/dist-packages/bar_chart_race/_make_chart.py:287: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([max_val] * len(ax.get_xticks()))
